# %% [markdown]
# # Day 10
# ### Exercise Level 1

# %%
def add_two_numbers(num1, num2):
    return num1 + num2

# Example usage:
result = add_two_numbers(3, 7)
print(result)  #Output should be 10
# Out:
# 10

# %% [markdown]
# ### Calculate the are of a circle

# %%
#Calculate the area of a circle using the formula: area = π x r x r.
def area_of_circle(radius):
    PI = 3.14
    return PI * radius ** 2

# Example usage:
circle_area = area_of_circle(5)
print(circle_area)  # Output should be the area of the circle with radius 5
# Out:
# 78.5
