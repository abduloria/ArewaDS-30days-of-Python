# %% [markdown]
# # Exercise 18

# %%
# Level 1
# Count the frequency of words in the paragraph
paragraph = 'I love teaching. If you do not love teaching what else can you love. I love Python if you do not love something which can give you all the capabilities to develop an application what else can you love.'

word_counts = {}
for word in paragraph.split():
    word_counts[word] = word_counts.get(word, 0) + 1

# Find the most frequent word
most_frequent_word = max(word_counts, key=word_counts.get)
frequency = word_counts[most_frequent_word]

print(f'The most frequent word is "{most_frequent_word}" with a frequency of {frequency}.')
# Out:
# The most frequent word is "you" with a frequency of 5.

# %%
# Level 2
# Check if a string is a valid Python variable
import re

def is_valid_variable(variable):
    return re.match(r'^[a-zA-Z_]\w*$', variable) is not None

# Test cases
print(is_valid_variable('first_name'))    # True
print(is_valid_variable('first-name'))    # False
print(is_valid_variable('1first_name'))   # False
print(is_valid_variable('firstname'))      # True
# Out:
# True
# False
# False
# True

# %%
#Level 3

# Clean the text and find three most frequent words
import re
from collections import Counter

def clean_text(text):
    return re.sub(r'[^a-zA-Z\s]', '', text).lower()

sentence = '''%I $am@% a %tea@cher%, &and& I lo%#ve %tea@ching%;. There $is nothing; &as& mo@re rewarding as educa@ting &and& @emp%o@wering peo@ple. ;I found tea@ching m%o@re interesting tha@n any other %jo@bs. %Do@es thi%s mo@tivate yo@u to be a tea@cher!?'''

cleaned_text = clean_text(sentence)
print(cleaned_text)

words_count = Counter(cleaned_text.split())
most_frequent_words = words_count.most_common(3)
print(f'Three most frequent words: {most_frequent_words}')
# Out:
# i am a teacher and i love teaching there is nothing as more rewarding as educating and empowering people i found teaching more interesting than any other jobs does this motivate you to be a teacher
# Three most frequent words: [('i', 3), ('a', 2), ('teacher', 2)]
