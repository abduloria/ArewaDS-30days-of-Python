# %%
```python
# Exercises: Level 1
# Exercise 1
age = int(input("Enter your age: "))
if age >= 18:
    print("You are old enough to learn to drive.")
else:
    remaining_years = 18 - age
    print(f"You need {remaining_years} more years to learn to drive.")

# Exercise 2
your_age = int(input("Enter your age: "))
my_age = 30
if my_age > your_age:
    age_difference = my_age - your_age
    plural = "s" if age_difference > 1 else ""
    print(f"You are {age_difference} year{plural} older than me.")
elif my_age < your_age:
    age_difference = your_age - my_age
    plural = "s" if age_difference > 1 else ""
    print(f"I am {age_difference} year{plural} older than you.")
else:
    print("We are the same age.")

# Exercise 3
a = float(input("Enter number one: "))
b = float(input("Enter number two: "))
if a > b:
    print(f"{a} is greater than {b}.")
elif a < b:
    print(f"{a} is smaller than {b}.")
else:
    print(f"{a} is equal to {b}.")

# Exercises: Level 2
# Exercise 1
score = int(input("Enter your score: "))
if 80 <= score <= 100:
    print("Grade: A")
elif 70 <= score <= 89:
    print("Grade: B")
elif 60 <= score <= 69:
    print("Grade: C")
elif 50 <= score <= 59:
    print("Grade: D")
else:
    print("Grade: F")

# Exercise 2
month = input("Enter the month: ").capitalize()
if month in ['September', 'October', 'November']:
    print("Season: Autumn")
elif month in ['December', 'January', 'February']:
    print("Season: Winter")
elif month in ['March', 'April', 'May']:
    print("Season: Spring")
elif month in ['June', 'July', 'August']:
    print("Season: Summer")
else:
    print("Invalid input.")

# Exercise 3
fruits = ['banana', 'orange', 'mango', 'lemon']
new_fruit = input("Enter a fruit: ").lower()
if new_fruit not in fruits:
    fruits.append(new_fruit)
    print(f"Modified list: {fruits}")
else:
    print("That fruit already exists in the list.")

# Exercises: Level 3
# Exercise 1
if 'skills' in person:
    skills = person['skills']
    if len(skills) > 1:
        middle_index = len(skills) // 2
        print(f"Middle skill: {skills[middle_index]}")

# Exercise 2
if 'skills' in person:
    skills = person['skills']
    if 'Python' in skills:
        print("The person has 'Python' skill.")
    else:
        print("The person does not have 'Python' skill.")

# Exercise 3
if 'skills' in person:
    skills = person['skills']
    if set(['JavaScript', 'React']).issubset(skills):
        print("He is a front end developer.")
    elif set(['Node', 'Python', 'MongoDB']).issubset(skills):
        print("He is a backend developer.")
    elif set(['React', 'Node', 'MongoDB']).issubset(skills):
        print("He is a fullstack developer.")
    else:
        print("Unknown title.")

# Exercise 4
if person.get('is_married') and person.get('country') == 'Finland':
    print(f"{person['first_name']} {person['last_name']} lives in {person['country']}. He is married.")
```

Note: The provided code assumes the existence of the `person` dictionary and its keys. Make sure to define `person` before running the code.
# Out:
#   File "<ipython-input-16-631ebbcf72ac>", line 1
#     ```python
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Day 9
# ### Exercises: Level 1
# ### Exercise 1
