# %% [markdown]
# # Exercise 17

# %%
names = ['Finland', 'Sweden', 'Norway', 'Denmark', 'Iceland', 'Estonia', 'Russia']
nordic_countries, *rest = names[:5]
es, ru = names[5:7]

print("Nordic Countries:", nordic_countries)
print("Estonia:", es)
print("Russia:", ru)
# Out:
# Nordic Countries: Finland
# Estonia: Estonia
# Russia: Russia
