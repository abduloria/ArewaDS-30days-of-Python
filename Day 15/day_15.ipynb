# %% [markdown]
# # Exercise 15

# %%
# Syntax Error

print 'hello world'
# Out:
#   File "<ipython-input-4-922e98eaf49d>", line 3
#     print 'hello world'
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
# Name Error

print(age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-35e1f7dfa897> in <cell line: 2>()
#       1 # Name Error
# ----> 2 print(age)
#
# NameError: name 'age' is not defined

# %%
# Index Error

numbers = [1, 2, 3, 4, 5]
numbers[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-989118f1cc3a> in <cell line: 4>()
#       2
#       3 numbers = [1, 2, 3, 4, 5]
# ----> 4 numbers[5]
#
# IndexError: list index out of range

# %%
# ModuleNotFoundError

import maths
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-6e25cba24411> in <cell line: 1>()
# ----> 1 import maths
#
# ModuleNotFoundError: No module named 'maths'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# AttributeError


import math
math.PI
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-4997bd7fdcb7> in <cell line: 2>()
#       1 import math
# ----> 2 math.PI
#
# AttributeError: module 'math' has no attribute 'PI'

# %%
# KeyError

users = {'name':'Asab', 'age':250, 'country':'Finland'}
users['name']
'Asab'
users['county']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-791a1b513573> in <cell line: 4>()
#       2 users['name']
#       3 'Asab'
# ----> 4 users['county']
#
# KeyError: 'county'

# %%
# TypeError

4 + '3'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-f6a78e10c39d> in <cell line: 3>()
#       1 #
#       2
# ----> 3 4 + '3'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# ImportError

from math import power
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-145000154605> in <cell line: 3>()
#       1 #
#       2
# ----> 3 from math import power
#
# ImportError: cannot import name 'power' from 'math' (unknown location)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# ValueError

int('12a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-6cae852100dd> in <cell line: 3>()
#       1 #
#       2
# ----> 3 int('12a')
#
# ValueError: invalid literal for int() with base 10: '12a'

# %%
# ZeroDivisionError

1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-16-c40a74c8223e> in <cell line: 3>()
#       1 # ZeroDivisionError
#       2
# ----> 3 1/0
#
# ZeroDivisionError: division by zero
